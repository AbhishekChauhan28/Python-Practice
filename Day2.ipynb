# %% [markdown]
# # Create a function that can accept two arguments - name & age and print its value.

# %%
def sample_fun(name,age):
    print ("Name is :" +name)
    print("age is : " +age)
sample_fun("Abhishek", "23")
# Out:
# Name is :Abhishek
# age is : 23

# %% [markdown]
# # Define a function overlapping() that takes two lists and returns True if they have at least one member in common, False otherwise

# %%
def overlapping(list_1, list_2) :
    for x in list_1:
        for y in list_2:
            if x == y :
                result = True
                return result
    return False

# %%
print(overlapping([12,2,23,12,1], [12,12,123,112,11]))
# Out:
# True

# %% [markdown]
# # Write a function called nested_sum() that takes a nested list of integers and add up the elements from all of the nested lists.

# %%
def sum1(lst):
    total = 0
    for element in lst:
        if (type(element) == type([])):
            total = total + sum1(element)
        else:
            total = total + element
    return total
print( "Sum is:",sum1([[[1,2,3],[4,[5,6]],7]]))
# Out:
# Sum is: 28

# %% [markdown]
# # Write a function find_longest_word() that takes a list of n words and returns the length of the longest one. Ask user how many words user he wants to enter (n) and accordingly ask user to enter words one by one

# %%
text = input("User enter the string Please! : ")
# Out:
# User enter the string Please! :  hey this is abhishek

# %%
a = text.split()
a
# Out:
# ['hey', 'this', 'is', 'abhishek']

# %%
def longestLength(a):
    max1 = len(a[0])
    temp = a[0]
  
    for i in a:
        if(len(i) > max1):
  
            max1 = len(i)
            temp = i
  
    print("The word with the longest length is:", temp," and length is ", max1)
find_longest_word(a)
# Out:
# The word with the longest length is: abhishek  and length is  8

# %% [markdown]
# # Write a function adder() which accepts random number of arguments of any data type (int, float, boolean, string) and returns sum of all the int and float values in it.
#     For eg: adder(1, 2, True, 9, "mango", 5.0) should return 17.0

# %%
text = (1,2,True,9,"mango",5.0)

# %%
def adder(mix_list) :
    sum = 0
    for i in mix_list:
        if type(i) == int or type(i) == float:
            sum += i
    return sum
print("Sum of int and float values : ", adder(text))
# Out:
# Sum of int and float values :  17.0

# %% [markdown]
# # Write a function centered_average(), that return the "centred" average of a list of integers. Centred average is the average of the values ignoring the largest and smallest values in the list. If there are multiple copies of the smallest value, ignore just one copy, and likewise for the largest value. List should be of length 3 or more.
#     centered_average([1, 2, 3, 4, 100]) → 3
#     centered_average([1, 1, 5, 5, 10, 8, 7]) → 5
#     centered_average([-10, -4, -2, -4, -2, 0]) → -3

# %%
my_list = ([1, 1, 5, 5, 10, 8, 7])

# %%
print("mid value is ",my_list[int(len(my_list)/2)])
# Out:
# mid value is  5

# %% [markdown]
# # Write a function called reduce_whitespace(), in a module named string_operations, that returns the line with all extra whitespace characters between words replaced with single space. Read the given file white_spaces.txt and apply this function reduce_whitespace(), by importing from module, on all the lines in the file and then save these lines in a new file.

# %%
myfile = open("E:\C-DAC Document\Python\Assignment\Day2\data_files\white_spaces.txt")

# %%
myfile.read()
# Out:
# ''

# %%
import string_operations

# %%
r = open("E:\C-DAC Document\Python\Assignment\Day2\data_files\white_spaces.txt", mode = 'r')
w = open("E:\C-DAC Document\Python\Assignment\Day2\data_files\white_spaces.txt", mode = 'w')
a = r.readlines()
for i in range(len(a)):
    z = string_operations.reduce_whitespace(a[i])
    w.write(z+ " \n")
w.close()
r.close
# Out:
# <function TextIOWrapper.close()>

# %% [markdown]
# # File movies_data.txt contains data about movies. Each line of this file contains data for 1 movie. Data is in following format:
#     movie_id::movie_name (release_rear)::genres
# ## If movie falls in more than one genre then those are separated by “|”.
#     E.g.: Comedy|Drama|Romance
# ## Based on the data in this file answer the following questions:

# %%
file = open("E:\C-DAC Document\Python\Assignment\Day2\data_files\movies_data.txt")

# %%
# 1.Find the number of movies released in every year in a dictionary. Sample output: {'1923': 3, '1930': 7, '1957': 20…}
d_year = {}
file.seek(0)
for line in file:
    words = line.split("::")
    year = words[1][-5:-1]
    d_year[year] = d_year.get(year, 0) + 1

# %%
d_year
# Out:
# {'1995': 342,
#  '1994': 257,
#  '1996': 345,
#  '1976': 21,
#  '1993': 165,
#  '1992': 102,
#  '1988': 69,
#  '1967': 24,
#  '1964': 16,
#  '1977': 22,
#  '1965': 20,
#  '1982': 50,
#  '1962': 20,
#  '1990': 77,
#  '1991': 60,
#  '1989': 60,
#  '1937': 11,
#  '1940': 19,
#  '1969': 18,
#  '1981': 43,
#  '1973': 29,
#  '1970': 16,
#  '1960': 15,
#  '1955': 19,
#  '1956': 19,
#  '1959': 22,
#  '1968': 22,
#  '1980': 41,
#  '1975': 21,
#  '1986': 104,
#  '1948': 12,
#  '1943': 10,
#  '1963': 25,
#  '1950': 14,
#  '1946': 13,
#  '1987': 71,
#  '1997': 315,
#  '1974': 28,
#  '1958': 22,
#  '1949': 10,
#  '1972': 22,
#  '1998': 337,
#  '1933': 7,
#  '1952': 11,
#  '1951': 12,
#  '1957': 20,
#  '1961': 19,
#  '1954': 15,
#  '1934': 7,
#  '1944': 13,
#  '1942': 13,
#  '1941': 11,
#  '1953': 14,
#  '1939': 11,
#  '1947': 14,
#  '1945': 11,
#  '1938': 6,
#  '1935': 6,
#  '1936': 8,
#  '1926': 8,
#  '1932': 7,
#  '1930': 7,
#  '1971': 26,
#  '1979': 32,
#  '1966': 12,
#  '1978': 30,
# ...

# %%
# 2. Find total number of movies starting with T or J.
file.seek(0)
count = 0
for line in file:
    words = line.split("::")
    print(words[1][0])
    if words[1][0] == "T" or words[1][0] == "J":
        count += 1
# Out:
# T
# J
# G
# W
# F
# H
# S
# T
# S
# G
# A
# D
# B
# N
# C
# C
# S
# F
# A
# M
# G
# C
# A
# P
# L
# O
# N
# P
# C
# S
# D
# T
# W
# B
# C
# D
# A
# I
# C
# C
# R
# D
# R
# M
# T
# H
# S
# P
# W
# U
# G
# M
# L
# B
# G
# K
# H
# P
# C
# I
# E
# M
# D
# T
# B
# L
# T
# F
# F
# F
# F
# K
# M
# B
# B
# S
# N
# C
# J
# W
# T
# A
# O
# L
# A
# W
# D
# B
# N
# J
# M
# V
# B
# B
# I
# H
# S
# H
# C
# B
# M
# U
# H
# B
# N
# M
# C
# H
# B
# T
# R
# B
# M
# H
# A
# Y
# I
# S
# R
# B
# B
# C
# S
# F
# N
# S
# J
# P
# A
# F
# J
# N
# S
# D
# F
# M
# N
# T
# U
# B
# S
# G
# B
# B
# A
# B
# A
# A
# A
# R
# A
# B
# B
# B
# B
# C
# C
# C
# C
# C
# C
# D
# D
# D
# D
# F
# F
# F
# H
# J
# J
# J
# J
# K
# L
# L
# L
# M
# M
# M
# M
# M
# N
# N
# N
# P
# P
# R
# S
# S
# S
# S
# S
# S
# S
# S
# S
# U
# T
# T
# T
# T
# U
# U
# U
# W
# W
# W
# W
# B
# B
# B
# B
# B
# B
# B
# B
# C
# C
# C
# C
# D
# D
# D
# D
# D
# D
# D
# D
# E
# E
# E
# E
# F
# F
# F
# G
# H
# F
# F
# G
# G
# G
# H
# H
# H
# I
# H
# H
# I
# ...

# %%
count
# Out:
# 304

# %%
# 3. How many comedy movies were released in 1995?
file.seek(0)
count = 0
for line in file:
    words = line.split("::")
    year = words[1][-5:-1]
    genre = words[2]
    if year == "1995" and "Comedy" in genre:
        count += 1

# %%
count
# Out:
# 89

# %%
# 4. How many action movies were released in 1993?
file.seek(0)
count = 0
for line in file:
    words = line.split("::")
    year = words[1][-5:-1]
    genre = words[2]
    if year == "1993" and "Action" in genre:
        count += 1

# %%
count
# Out:
# 25

# %% [markdown]
# # Using list comprehension create a list of natural numbers from 1-1000 that are divisible by 7.

# %%
list = [i for i in range(1,1001) if i % 7 == 0]

# %%
print(list)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245, 252, 259, 266, 273, 280, 287, 294, 301, 308, 315, 322, 329, 336, 343, 350, 357, 364, 371, 378, 385, 392, 399, 406, 413, 420, 427, 434, 441, 448, 455, 462, 469, 476, 483, 490, 497, 504, 511, 518, 525, 532, 539, 546, 553, 560, 567, 574, 581, 588, 595, 602, 609, 616, 623, 630, 637, 644, 651, 658, 665, 672, 679, 686, 693, 700, 707, 714, 721, 728, 735, 742, 749, 756, 763, 770, 777, 784, 791, 798, 805, 812, 819, 826, 833, 840, 847, 854, 861, 868, 875, 882, 889, 896, 903, 910, 917, 924, 931, 938, 945, 952, 959, 966, 973, 980, 987, 994]

# %% [markdown]
# # Given list of fruits, use dictionary comprehension to create a dictionary with fruits, the list elements, as the keys and the length of each string as the values.

# %%
fruits = ['apple', 'mango', 'banana', 'grapes', 'watermalen']

# %%
fruits = {f : len(f) for f in fruits}

# %%
fruits
# Out:
# {'apple': 5, 'mango': 5, 'banana': 6, 'grapes': 6, 'watermalen': 10}
